# %%
import sys
sys.path.append(r"/mnt/d/projects/thyroid_cancer_detection/")

# %%
from src.fibonacci_net import (
    FibonacciNet,
    FibonacciConvBlock,
    Avg2MaxPooling,
    PCB1,
    PCB2,
    DWSCBlock
)

# %%
import tensorflow as tf

model = tf.keras.models.load_model(
    "/mnt/d/projects/thyroid_cancer_detection/models/thyroid_fibonaccinet_best.keras",

    custom_objects={
        "FibonacciNet": FibonacciNet,
        "FibonacciConvBlock": FibonacciConvBlock,
        "Avg2MaxPooling": Avg2MaxPooling,
        "PCB1": PCB1,
        "PCB2": PCB2,
        "DWSCBlock": DWSCBlock
    }
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/tfgpu/lib/python3.11/site-packages/keras/src/models/model.py:839, in Model.from_config(cls, config, custom_objects)
#     838 try:
# --> 839     return cls(**config)
#     840 except TypeError as e:
#
# TypeError: FibonacciNet.__init__() got an unexpected keyword argument 'trainable'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/tfgpu/lib/python3.11/site-packages/keras/src/saving/serialization_lib.py:737, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     736 try:
# --> 737     instance = cls.from_config(inner_config)
#     738 except TypeError as e:
#
# File ~/miniconda3/envs/tfgpu/lib/python3.11/site-packages/keras/src/models/model.py:841, in Model.from_config(cls, config, custom_objects)
#     840 except TypeError as e:
# --> 841     raise TypeError(
#     842         "Unable to revive model from config. When overriding "
#     843         "the `get_config()` method, make sure that the "
#     844         "returned config contains all items used as arguments "
#     845         f"in the  constructor to {cls}, "
#     846         "which is the default behavior. "
#     847         "You can override this default behavior by defining a "
#     848         "`from_config(cls, config)` class method to specify "
#     849         "how to create an "
#     850         f"instance of {cls.__name__} from its config.\n\n"
#     851         f"Received config={config}\n\n"
#     852         f"Error encountered during deserialization: {e}"
#     853     )
#
# TypeError: Unable to revive model from config. When overriding the `get_config()` method, make sure that the returned config contains all items used as arguments in the  constructor to <class 'src.fibonacci_net.FibonacciNet'>, which is the default behavior. You can override this default behavior by defining a `from_config(cls, config)` class method to specify how to create an instance of FibonacciNet from its config.
#
# Received config={'num_classes': 1, 'activation': 'sigmoid', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}}
#
# Error encountered during deserialization: FibonacciNet.__init__() got an unexpected keyword argument 'trainable'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import tensorflow as tf
#       2
# ----> 3 model = tf.keras.models.load_model(
#       4     "/mnt/d/projects/thyroid_cancer_detection/models/thyroid_fibonaccinet_best.keras",
#       5
#       6     custom_objects={
#
# File ~/miniconda3/envs/tfgpu/lib/python3.11/site-packages/keras/src/saving/saving_api.py:188, in load_model(filepath, custom_objects, compile, safe_mode)
#     185         is_keras_zip = True
#     187 if is_keras_zip or is_keras_dir or is_hf:
# --> 188     return saving_lib.load_model(
#     189         filepath,
#     190         custom_objects=custom_objects,
#     191         compile=compile,
#     192         safe_mode=safe_mode,
#     193     )
#     194 if str(filepath).endswith((".h5", ".hdf5")):
#     195     return legacy_h5_format.load_model_from_hdf5(
#     196         filepath,
#     197         custom_objects=custom_objects,
#     198         compile=compile,
#     199         safe_mode=safe_mode,
#     200     )
#
# File ~/miniconda3/envs/tfgpu/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:362, in load_model(filepath, custom_objects, compile, safe_mode)
#     357     raise ValueError(
#     358         "Invalid filename: expected a `.keras` extension. "
#     359         f"Received: filepath={filepath}"
#     360     )
#     361 with open(filepath, "rb") as f:
# --> 362     return _load_model_from_fileobj(
#     363         f, custom_objects, compile, safe_mode
#     364     )
#
# File ~/miniconda3/envs/tfgpu/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:439, in _load_model_from_fileobj(fileobj, custom_objects, compile, safe_mode)
#     436 with zf.open(_CONFIG_FILENAME, "r") as f:
#     437     config_json = f.read()
# --> 439 model = _model_from_config(
#     440     config_json, custom_objects, compile, safe_mode
#     441 )
#     443 all_filenames = zf.namelist()
#     444 extract_dir = None
#
# File ~/miniconda3/envs/tfgpu/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:428, in _model_from_config(config_json, custom_objects, compile, safe_mode)
#     426 # Construct the model from the configuration file in the archive.
#     427 with ObjectSharingScope():
# --> 428     model = deserialize_keras_object(
#     429         config_dict, custom_objects, safe_mode=safe_mode
#     430     )
#     431 return model
#
# File ~/miniconda3/envs/tfgpu/lib/python3.11/site-packages/keras/src/saving/serialization_lib.py:739, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     737     instance = cls.from_config(inner_config)
#     738 except TypeError as e:
# --> 739     raise TypeError(
#     740         f"{cls} could not be deserialized properly. Please"
#     741         " ensure that components that are Python object"
#     742         " instances (layers, models, etc.) returned by"
#     743         " `get_config()` are explicitly deserialized in the"
#     744         " model's `from_config()` method."
#     745         f"\n\nconfig={config}.\n\nException encountered: {e}"
#     746     )
#     747 build_config = config.get("build_config", None)
#     748 if build_config and not instance.built:
#
# TypeError: <class 'src.fibonacci_net.FibonacciNet'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': None, 'class_name': 'FibonacciNet', 'config': {'num_classes': 1, 'activation': 'sigmoid', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}}, 'registered_name': 'FibonacciNet', 'build_config': {'input_shape': [None, 224, 224, 3]}, 'compile_config': {'optimizer': {'module': 'keras.optimizers', 'class_name': 'Adam', 'config': {'name': 'adam', 'learning_rate': 0.0002500000118743628, 'weight_decay': None, 'clipnorm': None, 'global_clipnorm': None, 'clipvalue': None, 'use_ema': False, 'ema_momentum': 0.99, 'ema_overwrite_frequency': None, 'loss_scale_factor': None, 'gradient_accumulation_steps': None, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}, 'registered_name': None}, 'loss': 'binary_crossentropy', 'loss_weights': None, 'metrics': ['accuracy', {'module': 'keras.metrics', 'class_name': 'Precision', 'config': {'name': 'precision', 'dtype': 'float32', 'thresholds': None, 'top_k': None, 'class_id': None}, 'registered_name': None}, {'module': 'keras.metrics', 'class_name': 'Recall', 'config': {'name': 'recall', 'dtype': 'float32', 'thresholds': None, 'top_k': None, 'class_id': None}, 'registered_name': None}, {'module': 'keras.metrics', 'class_name': 'AUC', 'config': {'name': 'auc', 'dtype': 'float32', 'num_thresholds': 200, 'curve': 'ROC', 'summation_method': 'interpolation', 'multi_label': False, 'num_labels': None, 'label_weights': None, 'from_logits': False}, 'registered_name': None}], 'weighted_metrics': None, 'run_eagerly': False, 'steps_per_execution': 1, 'jit_compile': True}}.
#
# Exception encountered: Unable to revive model from config. When overriding the `get_config()` method, make sure that the returned config contains all items used as arguments in the  constructor to <class 'src.fibonacci_net.FibonacciNet'>, which is the default behavior. You can override this default behavior by defining a `from_config(cls, config)` class method to specify how to create an instance of FibonacciNet from its config.
#
# Received config={'num_classes': 1, 'activation': 'sigmoid', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}}
#
# Error encountered during deserialization: FibonacciNet.__init__() got an unexpected keyword argument 'trainable'
